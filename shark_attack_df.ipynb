# %%
import pandas as pd

# %%
# !pip install xlrd

# %%
shark_attack = pd.read_excel("C:/Users/yurii/Downloads/IH_Projects/shark_attack/GSAF5.xls")

# %%
shark_attack.head(5)
# Out:
#               Date    Year        Type    Country              State  \
# 0   18th September  2026.0  Unprovoked  Australia  Western Australia
# 1   16th September  2026.0  Unprovoked     Canada             Quebec
# 2   14th September  2026.0  Unprovoked    Bahamas             Bimini
# 3  13th September   2026.0  Unprovoked  Australia  Western Australia
# 4    7th September  2026.0  Unprovoked        USA             Hawaii
#
#                                     Location  Activity  \
# 0                       Sorrento Beach Perth  Swimming
# 1  Off the coast of Perce Le Bilbo dive site    Diving
# 2                              Bimini Island  Swimming
# 3                                  Geraldton   Surfing
# 4                                   Honolulu   Surfing
#
#                         Name Sex   Age  ...                     Species   \
# 0                Greg O'Neil   M    63  ...  Great White Shark 6m (20ft)
# ...

# %%
shark_attack.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7125 entries, 0 to 7124
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7125 non-null   object
#  1   Year            7123 non-null   float64
#  2   Type            7107 non-null   str
#  3   Country         7075 non-null   str
#  4   State           6638 non-null   str
#  5   Location        6558 non-null   str
#  6   Activity        6542 non-null   str
#  7   Name            6907 non-null   str
#  8   Sex             6547 non-null   str
#  9   Age             4131 non-null   object
#  10  Injury          7089 non-null   str
#  11  Fatal Y/N       6564 non-null   object
#  12  Time            3598 non-null   object
#  13  Species         3994 non-null   str
#  14  Source          7105 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   str
#  17  href            6796 non-null   str
# ...
